# %%
import numpy as np
import tensorflow as tf
tf.random.set_seed(777)

# %%
mnist = tf.keras.datasets.mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train,x_test = x_train/255.0, x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.2221 - accuracy: 0.9352
# Epoch 2/5
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0962 - accuracy: 0.9713
# Epoch 3/5
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0690 - accuracy: 0.9778
# Epoch 4/5
# 60000/60000 [==============================] - 8s 133us/sample - loss: 0.0528 - accuracy: 0.9834
# Epoch 5/5
# 60000/60000 [==============================] - 8s 135us/sample - loss: 0.0421 - accuracy: 0.9863

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.06328126800043975, 0.982]
